# %%
import os
import env
import time
from openai import OpenAI
from agents import Agent, Runner, ModelSettings

os.environ["OPENAI_API_KEY"] = env.OPENAI_API_KEY

# %%
agent = Agent(
    name="Assistant", 
    instructions="You are a helpful assistant",
    model="gpt-5-nano",
    model_settings=ModelSettings(
        extra_args={"service_tier": "flex"},
    ),
)

# %%
result = await Runner.run(agent, "Write a haiku about recursion in programming.")

# %%
print(result.raw_responses)
print(result.final_output)
# Out:
# [ModelResponse(output=[ResponseReasoningItem(id='rs_0cc7c0de93f5b9f800696fcb32ecf48197841d0fe1f7181975', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_0cc7c0de93f5b9f800696fcb3a498481979f16bba027ebde71', content=[ResponseOutputText(annotations=[], text='Call itself again\ninto the depths it calls back\nwe begin anew', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], usage=Usage(requests=1, input_tokens=24, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=1492, output_tokens_details=OutputTokensDetails(reasoning_tokens=1472), total_tokens=1516, request_usage_entries=[]), response_id='resp_0cc7c0de93f5b9f800696fcb326040819795dfdcd9a500d191')]
# Call itself again
# into the depths it calls back
# we begin anew
